# %%
import json, os, pprint, time, re
from urllib import parse
import  requests as req
from bs4 import BeautifulSoup as bs
import urllib.request
import json

folderPath = 'result'
if not os.path.exists(folderPath):
    os.makedirs(folderPath)

# %%
# 內湖區餐廳

apikey = "AIzaSyCU_q_dEEi5lCFUTas-oKyE74V-jpHMaPQ"
longitude = 25.073454
latitude = 121.567646
url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurant&location={longitude}%2C{latitude}&radius=1000&fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry&language=ZH-TW&key={apikey}"

payload={}
headers = {}
while latitude < 122.6596878:

    response = req.request("GET", url, headers=headers, data=payload)

    results = response.text


    listData = []

    for a in range(20):
        listData.append({
                "place_id": response.json().get("results")[a].get("place_id"),
                "name": response.json().get("results")[a].get("name"),
                "compound_code": response.json().get("results")[a].get("compound_code"),
                "geometry": response.json().get("results")[a].get("geometry"),
                "formatted_address": response.json().get("results")[a].get("formatted_address"),
                "types": response.json().get("results")[a].get("types"),
                "price_level": response.json().get("results")[a].get("price_level"),
                "rating": response.json().get("results")[a].get("rating"),
                "user_ratings_total": response.json().get("results")[a].get("user_ratings_total"),
            })
            

    with open(f'{folderPath}/restaurant.json', "a", encoding='utf-8') as file:
        file.write(json.dumps(listData, ensure_ascii=False, indent=4))
        print("檔案存好了", latitude)

    latitude += 0.02
# Out:
# 檔案存好了 121.567646
# 檔案存好了 121.58764599999999
# 檔案存好了 121.60764599999999
# 檔案存好了 121.62764599999998
# 檔案存好了 121.64764599999998
# 檔案存好了 121.66764599999998
# 檔案存好了 121.68764599999997
# 檔案存好了 121.70764599999997
# 檔案存好了 121.72764599999996
# 檔案存好了 121.74764599999996
# 檔案存好了 121.76764599999996
# 檔案存好了 121.78764599999995
# 檔案存好了 121.80764599999995
# 檔案存好了 121.82764599999994
# 檔案存好了 121.84764599999994
# 檔案存好了 121.86764599999994
# 檔案存好了 121.88764599999993
# 檔案存好了 121.90764599999993
# 檔案存好了 121.92764599999992
# 檔案存好了 121.94764599999992
# 檔案存好了 121.96764599999992
# 檔案存好了 121.98764599999991
# 檔案存好了 122.00764599999991
# 檔案存好了 122.0276459999999
# 檔案存好了 122.0476459999999
# 檔案存好了 122.0676459999999
# 檔案存好了 122.08764599999989
# 檔案存好了 122.10764599999989
# 檔案存好了 122.12764599999988
# 檔案存好了 122.14764599999988
# 檔案存好了 122.16764599999988
# 檔案存好了 122.18764599999987
# 檔案存好了 122.20764599999987
# 檔案存好了 122.22764599999987
# 檔案存好了 122.24764599999986
# 檔案存好了 122.26764599999986
# 檔案存好了 122.28764599999985
# 檔案存好了 122.30764599999985
# 檔案存好了 122.32764599999985
# 檔案存好了 122.34764599999984
# 檔案存好了 122.36764599999984
# 檔案存好了 122.38764599999983
# 檔案存好了 122.40764599999983
# 檔案存好了 122.42764599999983
# 檔案存好了 122.44764599999982
# 檔案存好了 122.46764599999982
# 檔案存好了 122.48764599999981
# 檔案存好了 122.50764599999981
# 檔案存好了 122.5276459999998
# 檔案存好了 122.5476459999998
# 檔案存好了 122.5676459999998
# 檔案存好了 122.5876459999998
# 檔案存好了 122.60764599999979
# 檔案存好了 122.62764599999979
# 檔案存好了 122.64764599999978

# %%
# 北投區咖啡店

apikey = "AIzaSyCU_q_dEEi5lCFUTas-oKyE74V-jpHMaPQ"

longitude = 25.125809
latitude = 121.468798

url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurant&location={longitude}%2C{latitude}&radius=1000&fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry&language=ZH-TW&key={apikey}"

payload={}
headers = {}
while latitude < 121.496893:

    response = req.request("GET", url, headers=headers, data=payload)

    results = response.text


    listData = []

    for a in range(20):
        listData.append({
                "place_id": response.json().get("results")[a].get("place_id"),
                "name": response.json().get("results")[a].get("name"),
                "compound_code": response.json().get("results")[a].get("compound_code"),
                "geometry": response.json().get("results")[a].get("geometry"),
                "formatted_address": response.json().get("results")[a].get("formatted_address"),
                "types": response.json().get("results")[a].get("types"),
                "price_level": response.json().get("results")[a].get("price_level"),
                "rating": response.json().get("results")[a].get("rating"),
                "user_ratings_total": response.json().get("results")[a].get("user_ratings_total"),
            })
            

    with open(f'{folderPath}/restaurant.json', "a", encoding='utf-8') as file:
        file.write(json.dumps(listData, ensure_ascii=False, indent=4))
        print(longitude, "檔案存好了")

    longitude += 0.02
    latitude += 0.02

while longitude > 25.109583:

    response = req.request("GET", url, headers=headers, data=payload)

    results = response.text


    listData = []

    for a in range(20):
        listData.append({
                "place_id": response.json().get("results")[a].get("place_id"),
                "name": response.json().get("results")[a].get("name"),
                "compound_code": response.json().get("results")[a].get("compound_code"),
                "geometry": response.json().get("results")[a].get("geometry"),
                "formatted_address": response.json().get("results")[a].get("formatted_address"),
                "types": response.json().get("results")[a].get("types"),
                "price_level": response.json().get("results")[a].get("price_level"),
                "rating": response.json().get("results")[a].get("rating"),
                "user_ratings_total": response.json().get("results")[a].get("user_ratings_total"),
            })
            

    with open(f'{folderPath}/restaurant.json', "a", encoding='utf-8') as file:
        file.write(json.dumps(listData, ensure_ascii=False, indent=4))
        print("檔案存好了", longitude)

    longitude -= 0.02
    latitude -= 0.02
# Out:
# 25.125809 檔案存好了
# 25.145809 檔案存好了
# 檔案存好了 25.165809
# 檔案存好了 25.145809
# 檔案存好了 25.125809

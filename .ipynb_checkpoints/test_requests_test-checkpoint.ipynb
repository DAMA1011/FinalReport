# %%
import requests
from bs4 import BeautifulSoup
from requests_html import HTMLSession
from requests_html import AsyncHTMLSession

# %%
str1 = "JAJAJAJAJAJAJA"

# %%
import requests
import json
from datetime import datetime
import html2text
def parse_description(description_tag):
    h = html2text.HTML2Text()
    h.ignore_links = True
    description_text = h.handle(str(description_tag)) 
    return description_text

# %%
next_page_token = ""

# 設定biz_id(寫進url)
# biz_id = re.search(r"1s(0.*?\:.*?)[^a-zA-Z\d\s:]",i) # 寫成迴圈的時候要改一下
# if not biz_id:
#     print("Not a valid url.")
# biz_id = biz_id.groups()[0]

reviewData = []

while True:
    url = f'https://www.google.com/async/reviewSort?yv=3&async=feature_id:0x0:0x6c2a5228f2e31fb8,review_source:All%20reviews,sort_by:newestFirst,is_owner:false,filter_text:,associated_topic:,next_page_token:{next_page_token},_pms:s,_fmt:json'
    my_headers = {
                    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.82 Safari/537.36'
    
                }
    response = requests.get(url, headers=my_headers)

    response = response.text.removeprefix(")]}'")
    json_data = json.loads(response)["localReviewsProto"]
    review_data = json_data["other_user_review"]

    for result in review_data:
        personal_rating = result['star_rating']['value']
        author_name = result['author_real_name']
        review_date = result['publish_date']['localized_date']
        review_acquisition_date = datetime.now().strftime("%Y-%m-%d")
        if result.get('review_text'):
            review_text = parse_description(result['review_text']['full_html'])
        else:
            review_text = ""

        info_dict = {}        
        info_dict['author_name'] = author_name
        info_dict['personal_rating'] =  personal_rating             
        info_dict["review_date"] = review_date
        info_dict["review_text"] = review_text
        info_dict["review_acquisition_date"] = review_acquisition_date
#         info_dict["google_url"] = i
        reviewData.append(info_dict)

    next_page_token = json_data.get('next_page_token','').strip()
    if not next_page_token:
        break

reviews_info_header = list(reviewData[0].keys())
reviews_info_df = pd.DataFrame.from_records(reviewData,columns=reviews_info_header)
reviews_info_df.to_csv(f'./reviews/restaurant/{biz_id}_review.csv')
print(str(num) + ' 完成店名(review)' + place_name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [28], in <cell line: 12>()
#      19 response = response.text.removeprefix(")]}'")
#      20 json_data = json.loads(response)["localReviewsProto"]
# ---> 21 review_data = json_data["other_user_review"]
#      23 for result in review_data:
#      24     personal_rating = result['star_rating']['value']
#
# KeyError: 'other_user_review'

# %%
i = ""123""
type(i)
# Out:
#   Input In [42]
#     i = ""123""
#           ^
# SyntaxError: invalid syntax

# %%
asession = AsyncHTMLSession()
r = asession.get('https://www.google.com.tw/maps/place/%E9%AD%9A%E3%81%AE%E6%A3%A7(%E9%AD%9A%E4%B9%8B%E6%A3%A7)/data=!4m7!3m6!1s0x3442a94844003971:0x4aeef21e060b771a!8m2!3d25.0712473!4d121.5159715!16s%2Fg%2F11c1rfpcpf!19sChIJcTkAREipQjQRGncLBh7y7ko?authuser=0&hl=zh-TW&rclk=1')
# response = requests.get('https://www.google.com.tw/maps/place/%E9%AD%9A%E3%81%AE%E6%A3%A7(%E9%AD%9A%E4%B9%8B%E6%A3%A7)/data=!4m7!3m6!1s0x3442a94844003971:0x4aeef21e060b771a!8m2!3d25.0712473!4d121.5159715!16s%2Fg%2F11c1rfpcpf!19sChIJcTkAREipQjQRGncLBh7y7ko?authuser=0&hl=zh-TW&rclk=1')

# %%
def parse_description(description_tag):
    description_text = h.handle(str(description_tag)) 
    return description_text

# %%
url = 'https://www.google.com.tw/maps/place/%E9%AD%9A%E3%81%AE%E6%A3%A7(%E9%AD%9A%E4%B9%8B%E6%A3%A7)/data=!4m7!3m6!1s0x3442a94844003971:0x4aeef21e060b771a!8m2!3d25.0712473!4d121.5159715!16s%2Fg%2F11c1rfpcpf!19sChIJcTkAREipQjQRGncLBh7y7ko?authuser=0&hl=zh-TW&rclk=1'

# %%
from requests_html import HTMLSession

session = HTMLSession()

r = session.get('https://www.google.com.tw/maps/place/%E9%AD%9A%E3%81%AE%E6%A3%A7(%E9%AD%9A%E4%B9%8B%E6%A3%A7)/data=!4m7!3m6!1s0x3442a94844003971:0x4aeef21e060b771a!8m2!3d25.0712473!4d121.5159715!16s%2Fg%2F11c1rfpcpf!19sChIJcTkAREipQjQRGncLBh7y7ko?authuser=0&hl=zh-TW&rclk=1')

r.html.render()

# %%
import pandas as pd

df = pd.read_csv('./info/restaurant/place_info.csv', header=None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       97 non-null     int64
#  1   1       97 non-null     object
#  2   2       97 non-null     object
#  3   3       92 non-null     object
#  4   4       95 non-null     object
#  5   5       88 non-null     float64
#  6   6       45 non-null     object
#  7   7       97 non-null     object
#  8   8       97 non-null     object
#  9   9       97 non-null     int64
#  10  10      97 non-null     int64
#  11  11      97 non-null     int64
#  12  12      97 non-null     int64
#  13  13      91 non-null     object
#  14  14      47 non-null     object
#  15  15      84 non-null     object
#  16  16      5 non-null      object
#  17  17      97 non-null     object
# dtypes: float64(1), int64(5), object(12)
# memory usage: 13.8+ KB

# %%
df[df[5].isna()]
# Out:
#     0                                                  1           2   \
# 4    0  https://www.google.com.tw/maps/place/%E5%B7%B4...      巴八八小吃店
# 50   0  https://www.google.com.tw/maps/place/%E5%A4%A7...  大龍峒一生懸命黑白切
# 52   0  https://www.google.com.tw/maps/place/%E8%AE%9A...        讚賞麵屋
# 54   0  https://www.google.com.tw/maps/place/%E5%BE%B7...       德龍飲食店
# 61   0  https://www.google.com.tw/maps/place/%E6%B2%B9...       油條花生湯
# 65   0  https://www.google.com.tw/maps/place/%E4%BE%BF...   便當及古早味什錦麵
# 77   0  https://www.google.com.tw/maps/place/%E6%B2%B9...      油飯小吃麵店
# 93   0  https://www.google.com.tw/maps/place/%E7%94%9C...    甜在心地瓜QQ球
# 94   0  https://www.google.com.tw/maps/place/%E7%89%9B...        牛奶好棒
#
#                    3      4   5    6                       7   \
# 4                 NaN    NaN NaN  NaN           103大同區大龍街278號
# 50  4.0 星級  1,111 則評論   台灣餐廳 NaN  NaN   103台北市大同區重慶北路三段313巷1號
# 52    4.0 星級  338 則評論    中餐館 NaN  NaN     103台北市大同區大龍街 300巷3號
# 54                4.0    熟食店 NaN  NaN        103台北市大同區大龍街269號
# 61    3.8 星級  164 則評論     餐廳 NaN  NaN          103大同區大龍街302號前
# 65                3.0    中餐館 NaN  NaN        103台北市大同區大龍街242號
# 77                4.6  中式麵食店 NaN  NaN         103台北市大同區大龍街98號
# 93                NaN     餐廳 NaN  NaN       103台北市大同區大龍街271號前
# 94                NaN     餐廳 NaN  NaN        103台北市大同區大龍街255號
#
#                             8   9   10  11  12  \
# 4   Plus Code: 3GC8+98 大同區 台北市   0   0   0   0
# 50  Plus Code: 3GF7+MM 大同區 台北市   1   1   0   0
# 52  Plus Code: 3GC8+J6 大同區 台北市   1   0   1   1
# 54  Plus Code: 3GC8+P9 大同區 台北市   0   1   0   0
# 61  Plus Code: 3GC8+M8 大同區 台北市   1   1   0   0
# 65  Plus Code: 3G98+X8 大同區 台北市   1   1   0   0
# 77  Plus Code: 3G88+J8 大同區 台北市   1   1   0   0
# 93  Plus Code: 3GC8+M9 大同區 台北市   0   0   0   0
# 94  Plus Code: 3GC8+H9 大同區 台北市   0   0   0   0
#
#                                                    13  \
# 4                                                 NaN
# 50                                                NaN
# 52  星期二、17:30 到 20:30; 星期三、17:30 到 08:30; 星期四、17:3...
# 54                                                NaN
# 61  星期二、11:00 到 21:00; 星期三、11:00 到 21:00; 星期四、11:0...
# 65                                                NaN
# 77  星期二、09:00 到 15:30、17:00 到 20:00; 星期三、09:00 到 1...
# 93  星期二、14:30 到 22:00; 星期三、14:30 到 22:00; 星期四、14:3...
# 94  星期二、15:00 到 21:00; 星期三、15:00 到 21:00; 星期四、15:0...
#
#                                                    14             15    16  \
# 4                                                 NaN   02 2594 6785  永久停業
# 50                                                NaN            NaN   NaN
# 52  https://www.facebook.com/profile.php?id=100070...            NaN   NaN
# 54                                                NaN   02 2592 3233   NaN
# 61                                                NaN   02 2593 6170   NaN
# 65                                                NaN   02 2257 8548   NaN
# 77                                                NaN   0938 511 561   NaN
# 93                                                NaN            NaN  暫時關閉
# 94                                                NaN            NaN  暫時關閉
#
#             17
# 4   2022-11-15
# 50  2022-11-15
# 52  2022-11-15
# 54  2022-11-15
# 61  2022-11-15
# 65  2022-11-15
# 77  2022-11-15
# 93  2022-11-15
# 94  2022-11-15

# %%
import requests

response = requests.get('https://www.google.com/async/reviewSort?yv=3&async=feature_id:0x3442a94a1bfa68c7:0x8bb33009af6ec818,review_source:All%20reviews,sort_by:newestFirst,is_owner:false,filter_text:,associated_topic:,next_page_token:,_pms:s,_fmt:json')

# %%
response = response.text.removeprefix(")]}'")
response
# Out:
# '\n{"localReviewsProto":{"async_id_prefix":"","available_review_sources":[{"name":"All reviews","type":"ALL_REVIEWS"},{"name":"Google","type":"GOOGLE"}],"can_reply_to_review":false,"feature_id":"0x3442a94a1bfa68c7:0x8bb33009af6ec818","filter_text_if_not_found":"","gmb_listing_id":"12517594347471432815","is_hotel":false,"is_owner":false,"next_page_token":"CAESBkVnSUlDZw\\u003d\\u003d","other_user_review":[{"author_attribution_text":[{"text":"2 則評論","type":"REVIEW"}],"author_real_name":"蔡瓊英","can_private_reply_to_review":false,"flag_inappropriate":{"link_type":"EXTERNAL","text":"檢舉不當內容","url":"https://www.google.com/local/review/rap/report?postId\\u003dChdDSUhNMG9nS0VJQ0FnSURlallDSHlRRRAB\\u0026entityid\\u003dChdDSUhNMG9nS0VJQ0FnSURlallDSHlRRRItChZDSUhNMG9nS0VJQ0FnSURlallDSEtREhNDZ3dJaWJxdm1nWVFvS3VwNndFGi4KF0NJSE0wb2dLRUlDQWdJRGVqWUNIcVFFEhNDZ3dJaWJxdm1nWVFvS3VwNndFIhIJx2j6G0qpQjQRGMhurwkws4sqE0Nnd0lpYnF2bWdZUW9LdXA2d0U\\u0026wv\\u003d1\\u0026d\\u003d286732336"},"language":"zh-Hant","profile_photo_url":"https://lh3.googleusercontent.com/a/ALm5wu2eNB9MTcjEQrhqwbIrAttEtNYNzh-QeceWwFJw\\u003ds40-c-c0x00000000-cc-rp-mo-br100","profile_review_url":"https://www.google.com/maps/contrib/109738828434503584078?hl\\u003dzh-TW","publish_date":{"localized_date":"4 週前","style":"NONE"},"review_id":"ChdDSUhNMG9nS0VJQ0FnSURlallDSHlRRRAB","review_text":{"full_html":"看網站上的套餐感覺還不錯\\u003cbr\\u003e但坐下來點餐時\\u003cbr\\u003e老闆說今天只有賣\\u003cbr\\u003e豬腳套餐和百菇素食套餐\\u003cbr\\u003e這兩樣我都不喜歡\\u003cbr\\u003e心想那就點個豆花吧\\u003cbr\\u003e老闆說低消ㄧ定要點飲料\\u003cbr\\u003e不能點豆花\\u003cbr\\u003e朋友想點豆花當套餐附贈的飲品\\u003cbr\\u003e也不行 一定必須是飲料\\u003cbr\\u003e我覺得自己進了一家黑店！","snippet_html":"看網站上的套餐感覺還不錯\\u003cbr\\u003e但坐下來點餐時\\u003cbr\\u003e老闆說今天只有賣 ⋯⋯"},"share_url":"https://www.google.com/maps/reviews/data\\u003d!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURlallDSHlRRRAB!2m1!1s0x0:0x8bb33009af6ec818!3m1!1s2@1:CIHM0ogKEICAgIDejYCHyQE%7CCgwIibqvmgYQoKup6wE%7C?hl\\u003dzh-TW","source":{"name":"Google","type":"GOOGLE"},"source_icon_url":"search_logo.png","star_rating":{"value":1},"translated":false,"vote_review_xsrf_token":""},{"author_attribution_text":[{"text":"在地嚮導","type":"LOCAL_GUIDE"},{"text":"67 則評論","type":"REVIEW"},{"text":"107 張相片","type":"PHOTO"}],"author_real_name":"TSAIPOAN","can_private_reply_to_review":false,"flag_inappropriate":{"link_type":"EXTERNAL","text":"檢舉不當內容","url":"https://www.google.com/local/review/rap/report?postId\\u003dChZDSUhNMG9nS0VJQ0FnSURlZ3BLbFZREAE\\u0026entityid\\u003dChZDSUhNMG9nS0VJQ0FnSURlZ3BLbFZREi4KF0NJSE0wb2dLRUlDQWdJRGVncEtsMVFFEhNDZ3dJbkkzMm1RWVFxSnpRNFFJGi0KFkNJSE0wb2dLRUlDQWdJRGVncEtsTlESE0Nnd0luSTMybVFZUXFKelE0UUkiEgnHaPobSqlCNBEYyG6vCTCziyoTQ2d3SW5JMzJtUVlRcUp6UTRRSQ\\u0026wv\\u003d1\\u0026d\\u003d286732336"},"language":"zh-Hant","profile_photo_url":"https://lh3.googleusercontent.com/a-/ACNPEu-0mSytlDGhhZOiQ-4FBD9kR-ql1HlApm8kFWl_pA\\u003ds40-c-c0x00000000-cc-rp-mo-ba4-br100","profile_review_url":"https://www.google.com/maps/contrib/102721345544224264800?hl\\u003dzh-TW","publish_date":{"localized_date":"1 個月前","style":"NONE"},"review_id":"ChZDSUhNMG9nS0VJQ0FnSURlZ3BLbFZREAE","review_text":{"full_html":"沒來過果然文創就不能說你來過大龍洞"},"share_url":"https://www.google.com/maps/reviews/data\\u003d!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSURlZ3BLbFZREAE!2m1!1s0x0:0x8bb33009af6ec818!3m1!1s2@1:CIHM0ogKEICAgIDegpKlVQ%7CCgwInI32mQYQqJzQ4QI%7C?hl\\u003dzh-TW","source":{"name":"Google","type":"GOOGLE"},"source_icon_url":"search_logo.png","star_rating":{"value":5},"translated":false,"vote_review_xsrf_token":""},{"author_attribution_text":[{"text":"在地嚮導","type":"LOCAL_GUIDE"},{"text":"42 則評論","type":"REVIEW"},{"text":"65 張相片","type":"PHOTO"}],"author_real_name":"胡永佳","can_private_reply_to_review":false,"flag_inappropriate":{"link_type":"EXTERNAL","text":"檢舉不當內容","url":"https://www.google.com/local/review/rap/report?postId\\u003dChdDSUhNMG9nS0VJQ0FnSURla0xiUm1BRRAB\\u0026entityid\\u003dChdDSUhNMG9nS0VJQ0FnSURla0xiUm1BRRItChZDSUhNMG9nS0VJQ0FnSURla0xiUldBEhNDZ3dJbk12V21RWVEyT ...

# %%
import pandas as pd
import os
import

# %%
df = pd.read_csv("raw_data/restaurant/review/0.csv")

# %%
pd.set_option("display.max_rows",380)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               380 non-null    int64
#  1   author_name              380 non-null    object
#  2   personal_rating          380 non-null    int64
#  3   review_date              380 non-null    object
#  4   review_text              264 non-null    object
#  5   review_acquisition_date  380 non-null    object
#  6   google_url               380 non-null    object
#  7   biz_id                   380 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 23.9+ KB

# %%
df
# Out:
#      Unnamed: 0              author_name  personal_rating review_date  \
# 0             0                    ammmo                4        2 天前
# 1             1               Going Keep                5        4 天前
# 2             2                      楊宥迎                4        4 天前
# 3             3                      李哲瑋                4        1 週前
# 4             4                      吳瑞林                1        2 週前
# 5             5                      王昶文                4        2 週前
# 6             6                    GPM骷鬼                5        2 週前
# 7             7                       小佐                5        2 週前
# 8             8                      林庭毅                2        3 週前
# 9             9                邱芷嫻 Sammy                5        4 週前
# 10           10                      楊良偉                3       1 個月前
# 11           11               Wu Yung Lu                4       1 個月前
# ...

# %%
df = df.dropna(subset="review_text")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 264 entries, 0 to 379
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               264 non-null    int64
#  1   author_name              264 non-null    object
#  2   personal_rating          264 non-null    int64
#  3   review_date              264 non-null    object
#  4   review_text              264 non-null    object
#  5   review_acquisition_date  264 non-null    object
#  6   google_url               264 non-null    object
#  7   biz_id                   264 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 18.6+ KB

# %%
df = df.drop_duplicates(subset=["review_text","author_name"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 264 entries, 0 to 379
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               264 non-null    int64
#  1   author_name              264 non-null    object
#  2   personal_rating          264 non-null    int64
#  3   review_date              264 non-null    object
#  4   review_text              264 non-null    object
#  5   review_acquisition_date  264 non-null    object
#  6   google_url               264 non-null    object
#  7   biz_id                   264 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 18.6+ KB

# %%
df["review_text"]
# Out:
# 0                                          還不錯，肉很好吃。\n\n
# 1      北投巷弄竟然有那麼日式的拉麵，厲害，叉燒肥但非常入味，瘦肉一點都不柴，對愛吃肥一點的人根本是...
# 3      黑曜拉麵  \n蒜頭味很重的雞湯 配上撒的蒜酥 香氣十足  \n肉是控肉不是叉燒 整題吃下來...
# 4                                        漲價就算了 湯越給越少\n\n
# 5      晚上七點半左右到訪，並沒有其他客人。店內有一位阿嬤跟一位較年輕的先生。點餐前問了一下+60豪...
# 6      身為住附近的拉麵宅終於來吃了  \n本來期望不高的  \n但實際來用餐  \n發現餐點的品質...
# 8      又鹹又油，吃完覺得腎臟減少20年的使用年限... 真的超級鹹  \n  \n回覆店家: 算術...
# 9            雖然店內沒有冷氣有點熱  \n但拉麵真不錯 用料實在  \n個人覺得Cp值很高\n\n
# 13                          辣度椒麻》辛辣，麵只有一片叉燒偏肥，但味道不錯。\n\n
# 16                                               有點油\n\n
# 18     湯頭濃鹹，細麵條是偏硬的那種但蠻好吃的，椒麻拉麵的口味比較特別，內用座位少且有某種腥味（可能...
# 20                       黑蒜頭拉麵很特別,湯頭濃郁,只是店內非常熱,不適合內用\n\n
# 22     黑曜拉麵超鹹，湯跟肉都很油、也沒有水可以配  \n老闆娘很奇怪，中間有一大半的位子不給客人坐...
# 23     味道我沒很在意就不說了.我是點了黑曜拉麵和海南雞飯,單就份量來說都挺少的,當正餐來說吃不飽-...
# 24                                        黑蒜拉麵很特別，好吃\n\n
# 25     椒麻、黑曜都不錯。  \n黑曜我請老闆煮淡一點，剛剛好。是我喜歡的味道。  \n椒麻 小孩說...
# ...

# %%
def chech_review(i):
    try:
        df = pd.read_csv(f"raw_data/restaurant/review/{i}")
        df = df.iloc[:,1:]
        df = df.dropna(subset="review_text")
        df = df.drop_duplicates(subset=["author_name"])
        df = df.drop_duplicates(subset=["review_text"])
        series = df["review_text"].str.findall("[\u4e00-\u9fa5]")
        series = series.str.len()
        df1 = df[series>10]
        df1 = pd.DataFrame(df1)
        df1
        df1.to_csv(f"raw_data/restaurant/review_clean/{i}")
    except:
        print(i)

# %%
df = pd.read_csv(f"raw_data/restaurant/review/0.csv")
df = df.iloc[:,1:]
df = df.dropna(subset="review_text")
df = df.drop_duplicates(subset=["author_name"])
df = df.drop_duplicates(subset=["review_text"])
series = df["review_text"].str.findall("[\u4e00-\u9fa5]")
series = series.str.len()
df1 = df[series>10]
df1 = pd.DataFrame(df1)
df1
# df1.to_csv(f"raw_data/restaurant/review_clean/{i}")
# Out:
#                  author_name  personal_rating review_date  \
# 1                 Going Keep                5        4 天前
# 3                        李哲瑋                4        1 週前
# 5                        王昶文                4        2 週前
# 6                      GPM骷鬼                5        2 週前
# 8                        林庭毅                2        3 週前
# 9                  邱芷嫻 Sammy                5        4 週前
# 13                       柯宗男                4       1 個月前
# 18                       黃書涵                4       2 個月前
# 20                 Wu Evelyn                3       2 個月前
# 22                        巧宇                2       3 個月前
# 23                       林振弘                2       3 個月前
# 25               wellworth65                4       3 個月前
# 28                      陳Amo                5       3 個月前
# 29                       啟仁高                5       3 個月前
# 30                       Joy                5       3 個月前
# ...

# %%
df = pd.read_csv(f"raw_data/restaurant/review/0.csv")
df = df.iloc[:,1:]
df = df.dropna(subset="review_text")
df = df.drop_duplicates(subset=["author_name"])
df = df.drop_duplicates(subset=["review_text"])

# %%
series = df["review_text"].str.findall("[\u4e00-\u9fa5]")

# %%
series
# Out:
# 0                                  [還, 不, 錯, 肉, 很, 好, 吃]
# 1      [北, 投, 巷, 弄, 竟, 然, 有, 那, 麼, 日, 式, 的, 拉, 麵, 厲, ...
# 3      [黑, 曜, 拉, 麵, 蒜, 頭, 味, 很, 重, 的, 雞, 湯, 配, 上, 撒, ...
# 4                         [漲, 價, 就, 算, 了, 湯, 越, 給, 越, 少]
# 5      [晚, 上, 七, 點, 半, 左, 右, 到, 訪, 並, 沒, 有, 其, 他, 客, ...
# 6      [身, 為, 住, 附, 近, 的, 拉, 麵, 宅, 終, 於, 來, 吃, 了, 本, ...
# 8      [又, 鹹, 又, 油, 吃, 完, 覺, 得, 腎, 臟, 減, 少, 年, 的, 使, ...
# 9      [雖, 然, 店, 內, 沒, 有, 冷, 氣, 有, 點, 熱, 但, 拉, 麵, 真, ...
# 13     [辣, 度, 椒, 麻, 辛, 辣, 麵, 只, 有, 一, 片, 叉, 燒, 偏, 肥, ...
# 16                                             [有, 點, 油]
# 18     [湯, 頭, 濃, 鹹, 細, 麵, 條, 是, 偏, 硬, 的, 那, 種, 但, 蠻, ...
# 20     [黑, 蒜, 頭, 拉, 麵, 很, 特, 別, 湯, 頭, 濃, 郁, 只, 是, 店, ...
# 22     [黑, 曜, 拉, 麵, 超, 鹹, 湯, 跟, 肉, 都, 很, 油, 也, 沒, 有, ...
# 23     [味, 道, 我, 沒, 很, 在, 意, 就, 不, 說, 了, 我, 是, 點, 了, ...
# 24                           [黑, 蒜, 拉, 麵, 很, 特, 別, 好, 吃]
# 25     [椒, 麻, 黑, 曜, 都, 不, 錯, 黑, 曜, 我, 請, 老, 闆, 煮, 淡, ...
# ...

# %%
series = series.str.len()
series
# Out:
# 0        7
# 1      139
# 3       40
# 4       10
# 5      388
# 6      116
# 8       33
# 9       28
# 13      20
# 16       3
# 18      56
# 20      24
# 22      94
# 23      93
# 24       9
# 25      77
# 28      25
# 29      12
# 30      13
# 31      22
# 32     199
# 33      99
# 34     104
# 35      17
# 37      34
# 39      58
# 40      49
# 41      36
# 42      29
# 44      14
# 45     157
# 46      27
# 47      28
# 48      88
# 50      88
# 51     242
# 52      39
# 53      24
# 54      13
# 55      16
# 56      13
# 57      50
# 58      50
# 59      13
# 61      87
# 63       8
# 64      17
# 67       9
# 71       2
# 73      73
# 74       8
# 76     106
# 78     151
# 79       5
# 80      37
# 81      40
# 82      30
# 84      10
# 87      76
# 88      71
# 89       6
# 90      55
# 92      20
# 94     323
# 96     114
# 97      27
# 98      75
# 99      37
# 101    121
# 102    123
# 103     33
# 104     45
# 108     92
# 109    334
# 111     60
# 112    134
# ...

# %%
file = os.listdir("raw_data/restaurant/review/")

for i in file:
    chech_review(i)
# Out:
# 20178.csv

# %%
for i in r
for i 
file
# Out:
# ['0.csv',
#  '1.csv',
#  '10.csv',
#  '100.csv',
#  '1000.csv',
#  '10000.csv',
#  '10001.csv',
#  '10002.csv',
#  '10003.csv',
#  '10004.csv',
#  '10005.csv',
#  '10006.csv',
#  '10007.csv',
#  '10008.csv',
#  '10009.csv',
#  '1001.csv',
#  '10010.csv',
#  '10011.csv',
#  '10012.csv',
#  '10013.csv',
#  '10014.csv',
#  '10015.csv',
#  '10016.csv',
#  '10017.csv',
#  '10018.csv',
#  '10019.csv',
#  '1002.csv',
#  '10020.csv',
#  '10021.csv',
#  '10022.csv',
#  '10023.csv',
#  '10024.csv',
#  '10025.csv',
#  '10026.csv',
#  '10027.csv',
#  '10028.csv',
#  '10029.csv',
#  '1003.csv',
#  '10030.csv',
#  '10031.csv',
#  '10032.csv',
#  '10033.csv',
#  '10034.csv',
#  '10035.csv',
#  '10036.csv',
#  '10037.csv',
#  '10038.csv',
#  '10039.csv',
#  '1004.csv',
#  '10040.csv',
#  '10041.csv',
#  '10042.csv',
#  '10043.csv',
#  '10044.csv',
#  '10045.csv',
#  '10046.csv',
#  '10047.csv',
#  '10048.csv',
#  '10049.csv',
#  '1005.csv',
#  '10050.csv',
#  '10051.csv',
#  '10052.csv',
# ...
